# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.neighbors import NearestNeighbors
from sklearn import ensemble
from sklearn.metrics import classification_report
from scipy.spatial import KDTree,distance_matrix, cKDTree

# %%
x = pd.read_csv("train_features.csv")
y = pd.read_csv("train_labels.csv")
y = y.drop(["id"],axis=1)
test_features = pd.read_csv("test_features.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
x["lga"].isna().sum()
# Out:
# 0

# %%
x["location_approximation"] = x["basin"] + x["region"] +x["lga"]

# %%
x.shape
# Out:
# (59400, 41)

# %%
x_work =pd.DataFrame(x[["location_approximation","longitude","latitude"]])

# %%
x_work = x_work.replace(0,np.nan)
x_work = x_work.dropna()

# %%
x_work.shape
# Out:
# (57588, 3)

# %%
z = x_work.groupby(["location_approximation"]).agg({ 'longitude':np.mean,'latitude':np.mean})

# %%
z["longitude"].min()
# Out:
# 29.688753471126756

# %%
x["location_approximation"].head()
# Out:
# 0                   Lake NyasaIringaLudewa
# 1               Lake VictoriaMaraSerengeti
# 2                  PanganiManyaraSimanjiro
# 3    Ruvuma / Southern CoastMtwaraNanyumbu
# 4               Lake VictoriaKageraKaragwe
# Name: location_approximation, dtype: object

# %%
z = x.groupby(["location_approximation"]).agg({ 'longitude':np.mean,'latitude':np.mean})

# %%
z.shape
# Out:
# (184, 2)

# %%
lmax = x["latitude"].max()
for i in range(len(x["latitude"])):
    if x["latitude"][i] == lmax:
        x.latitude[i] = z.loc[ x["location_approximation"][i] ][1]
# Out:
# C:\Users\cwcol\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
lmin = x["longitude"].min()
for i in range(len(x["longitude"])):
    if x["longitude"][i] < 25:
        x.longitude[i] = z.loc[ x["location_approximation"][i] ][0]
# Out:
# C:\Users\cwcol\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
z.loc["Lake VictoriaMwanzaGeita"]
# Out:
# longitude    0.000000e+00
# latitude    -2.000000e-08
# Name: Lake VictoriaMwanzaGeita, dtype: float64

# %%
tree = KDTree(x[["longitude","latitude"]].values)
tree.data
r = tree.query([38.486161,-11.0])[1]
x[["longitude","latitude"]].iloc[r]
# Out:
# longitude    38.458790
# latitude    -10.972057
# Name: 38343, dtype: float64

# %%
type(tree.data)
# Out:
# numpy.ndarray

# %%
df = x[["longitude","latitude"]]

# %%
tree = cKDTree(df.values)
i = 1
q = df.iloc[i]
tree.tree

# %%
nearest_fountains_long = []
nearest_fountains_lat = []
#for i in range(len(x[["longitude","latitude"]])):
tree = cKDTree(df.values)
def f1(i):
    q = df.iloc[i]
    t = df.drop(i)
    tree =cKDTree(t.values)
    return nearest_fountains_lat.append([t.iloc[tree.query(q)[1]][0]])

def f2(i):
    q = df.iloc[i]
    t = df.drop(i)
    tree =cKDTree(t.values)
    return nearest_fountains_lat.append([t.iloc[tree.query(q)[1]][1]])

# %%
x.shape
# Out:
# (59400, 52)

# %%
# %timeit cKDTree(df.values)
# Out:
# 254 ms ± 710 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit f2(0)
# Out:
# 195 ms ± 315 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
nearest_fountains_long = [ f1(i) for i in range(0,59400)]
nearest_fountains_lat = [f2(i) for i in range(0,59400)]

# %%
nearest_fountains_long
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
tree.count_neighbors(other = [38.486161,-11.155298],r=0.05)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-b9e2e94551c0> in <module>()
# ----> 1 tree.count_neighbors(other = [38.486161,-11.155298],r=0.05)
#
# ~\Anaconda3\lib\site-packages\scipy\spatial\kdtree.py in count_neighbors(self, other, r, p)
#     865
#     866         R1 = Rectangle(self.maxes, self.mins)
# --> 867         R2 = Rectangle(other.maxes, other.mins)
#     868         if np.shape(r) == ():
#     869             r = np.array([r])
#
# AttributeError: 'list' object has no attribute 'maxes'

# %% [markdown]
# # Distance formula complete

# %%
dar_es_salaam = (39.28333,-6.8)
mwanza = (32.9,-2.516667)
arusha = (36.683333,-3.366667)
dodoma = (35.741944,-6.173056)
mbeya = (33.45,-8.9)
morongoro = (37.66667,-6.816667)
tanga = (39.1,-5.0666667)
kahama = (32.6,-3.8375)
tabora = (32.8,-5.016667)
zanzibar = (39.199,-6.165)

# %%
dar_es_salaam[0]
# Out:
# 39.28333

# %%
x["dar_es_salaam"] = np.sqrt( (x["longitude"] - dar_es_salaam[0])**2 + ( x["latitude"]  - dar_es_salaam[1] )**2 )
x["mwanza"] = np.sqrt( (x["longitude"] - mwanza[0])**2 + ( x["latitude"]  - mwanza[1] )**2 )
x["arusha"] = np.sqrt( (x["longitude"] - arusha[0])**2 + ( x["latitude"]  - arusha[1] )**2 )
x["dodoma"] = np.sqrt( (x["longitude"] - dodoma[0])**2 + ( x["latitude"]  - dodoma[1] )**2 )
x["mbeya"] = np.sqrt( (x["longitude"] - mbeya[0])**2 + ( x["latitude"]  - mbeya[1] )**2 )
x["morongoro"] = np.sqrt( (x["longitude"] - morongoro[0])**2 + ( x["latitude"]  - morongoro[1] )**2 )
x["tanga"] = np.sqrt( (x["longitude"] - tanga[0])**2 + ( x["latitude"]  - tanga[1] )**2 )
x["kahama"] = np.sqrt( (x["longitude"] - kahama[0])**2 + ( x["latitude"]  - kahama[1] )**2 )
x["tabora"] = np.sqrt( (x["longitude"] - tabora[0])**2 + ( x["latitude"]  - tabora[1] )**2 )
x["zanzibar"] = np.sqrt( (x["longitude"] - zanzibar[0])**2 + ( x["latitude"]  - zanzibar[1] )**2 )

# %%
x["distance_to_nearest_city"] = x.loc[: , ["dar_es_salaam","mwanza","arusha","dodoma","mbeya","morongoro","tanga","kahama","tabora","zanzibar"]].min(axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
col_solo = ["id", "distance_to_nearest_city", "dar_es_salaam","mwanza","arusha","dodoma","mbeya","morongoro","tanga","kahama","tabora","zanzibar"]
pipeline = make_pipeline(
LogisticRegression(C=100)
)
pipeline.fit(x_train[col_solo],y_train)
y_pred = pipeline.predict(x_test[col_solo])
accuracy_score(y_test,y_pred)
# Out:
# C:\Users\cwcol\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5588552188552188

# %%
col_solo = ["id", "distance_to_nearest_city", "dar_es_salaam","mwanza","arusha","dodoma","mbeya","morongoro","tanga",\
            "kahama","tabora","zanzibar"]
x[col_solo].to_csv("cities.csv",index=False)
